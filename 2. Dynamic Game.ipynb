# %% [markdown]
# ![Hunger Game Movie Image](hun.img.png)
# Torres, 2023
#
#    **Welcome to the world of the [Hunger Games](https://www.looper.com/810795/the-entire-hunger-games-timeline-explained/)!**
#
# You are about to embark on a journey into Panem, the last living civilization on Earth.  Set in a world where only twelve districts remain following a failed rebellion that eradicated District 13 seventy-five years ago.
#
# The Hunger Games is an annual event during which two Tributes from each district are selected by lottery to compete in a televised barbaric battle to death.
# The rules are simple: only the last surviving Tribute will win, and the Hunger Games must continue until all other Tributes are eliminated (Thoman, 2023).
#
# The Hunger Games not only serve as entertainment but also as a reminder to the district of the Capitol's ever-present and ruthless power (Thoman, 2023).
#
# In this adventure, you will be thrown into the 74th ceremony of the Hunger Games.
# As Tribute, you must navigate the hostilities, be quick on your feet, make life-or-death decisions, and form alliances, all in the hope of emerging victorious from this cruel battle.
#
# May the odds be ever in your favor!
#
# **A special note to our Tributes:**
#
# This game should not contain any bugs or errors.
# To avoid any issues, make sure to follow the instruction closely and respect the entry requirement.

# %%
# import color to have colored text in my game
import colorama 
from colorama import Fore

#import time so I can manage the speed of my game   
import time

#import system so players can 'exit' the game once they've won!
import sys

### INTRO/ START OF THE GAME ###
def intro(): 
    
    #copy/pasting the MockinJay image into the code, - a huge symbol in the Hunger Games
    print(Fore.RED + """
                                                                            
                                                        +*++==-+#*      =**    ##+                  
                                                      =**+=::++*---==  +*#*  *#%#                   
                                          *******++++:+++-::--:-+#%+  +### +*%#*                               
                                -:::-::::::::::--::+=+--::-+--=*+*=+*##*+*%#*  %#                   
                             :::::::::::::---=+++-+==*::-:-*#+++**+==*+##%## *%#*                   
                          ..::::::::::::.....::+==+#---:++-:-#%#++*++=-+##+*##%                     
                        ...:::::::::          #%==*+=+-*-::##+=**++++++**++##*                       
                      ......:::::            ###*=*=+:.-#-:+##%#*+*+++++*+++=*#%*                   
                    -::...::::--            #%##*=*::+=:-=::+%%%+=-=**++++*+++                      
                  -:::..:::---             %%+**-=+:-=:.:*%@@%%*+=-==*#++++++==                                
               -:::::::-+                 #%%+*%++++++--=#%@@%#**++=++=+**+***++++++                 
              -:::::::=*                  *%@+*#**==**+=+#%@%#*#***+*=*#*#@##**+++++#                
             -:::::::+#                  *%%%*%***=+**+=+%%@*+****-+-=#*%%   #***++=+                
            :::::::+#                   *#%%#%##*=+*##+=*%@*****+*--:*+      #***+===               
           ..:::::+#                    #%#@+%%%*==+*%###%@#**++++#%          ****+==               
          ..:::::=#                     #@#%#%%%#+=-+##%#%%#++++#%%            =*++=-:              
          ..:::::+                      #@%@##%%#*+==+*%@%@#=**#+              :-++=--              
          .:-::::-                      #%*%##%%#**+==+*%%@+*++#*               :+==-=-             
          .:-::...                     #+@*@#*##****+==*#@%*+-*                 :===--:             
          .--::...         %@          +*%#%####****##%%@%#+==                  :===--:             
          :--::...        -*@        -+*%##%**##*+++*%@@@@+**                   --=---:             
          ---::::-       ==#%*     --*+##%%#+*##*+++%@@@@##%#                   --=---:             
          :--::::-      %++*%#--::==#%%%%%%#%#***##@@@@%%##                    --==----             
           :--:::=      #=#@@@%###@*#@%####@%*%@@@@@@@@%#                      :-------             
           *=----=%    #:=-%@#@@@@@@@@@@@@@@@@@@@%#%%                          :------              
            +==--=##  ::*+###%@%#*@%%@@@@%%@@@@@@@@%=-                        .-------              
            #*++==+- +-%#@@%+=  -=++*#%@@@@@%#@@@@@@@@*:                     -:------               
             %*++++=.+#@@@#=      :-*%%#+::..::=*##%%#%@#:                   --------               
              ##****++%#+-          -+#%%%##%%#*#==+*#**#@=.               ==----==-                
               ####*+%%                -=++=-     -=*#%%%#%#:             =---====-                 
               %%@#*#@%%%                           =*##%%##%-:          =---==++-                  
                 **@@@@@%%                           +*###%%#@=+        +=-=*##*=                   
                +#%@@@@@@%%%                          *%%%%%@##:=     ##*+*###*+                    
               *#  %%@@@@@@%%%                        %%%%%@%%#+:  ##%%@@%%%#*                      
              #      %@@@@@@@@%                        %%%%%%%%%%%*--#%@@@@@@%%#                       
                      #%@@@@@@@@@%                     %%%%%%%%%%#*:%@@@@@%%%                         
                         %%@@@@@@@@@%%                 %@@%%%%%%%*-@@@%%%                           
                           #%@@@@@@@@@@@@%%%%%%%%%%%%%%@@@@@@@%%%%+*%%                              
                              %%%@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@%%%+#                                                         
                                       %%%%%%%%%%%%%%%@%%%#      @@@#%                              
                                                     @#           @@@%@                             
                                                    @%             @@@%@                            
                                                                     @@@@                           
                                                                      @@@                           
                                                                       @@@@                         
                                                                        @@@                        
                                                                          @@      
    """ + Fore.RESET)
    #Fore.RED is called to turn the ASCI ART in red
    #Fore.RESET is used to reset text to original color
    
    #Introduction script to put players into the context of the game
    print("""
        The Hunger Games were established 75 years ago as a reminder and symbol of the Capitol's power. 
        Each year, twenty-four children of Panem are selected as Tributes during the Reaping ceremony.
                                    Two Tributes per district.\n
            But don't be fooled; being chosen as a Tribute is not an honor; it's a death sentence.\n
                        The 74th Hunger Games Reaping ceremony is about to begin. 
            Make your way to the Hall of Justice to find out who this year's Tributes will be.\n """)
    
    #GAME STARTS:
    while True:
        try:
            start_game = input(prompt = 'Press <ENTER> to start the game :\n')
            if start_game == "":
                break  # Break the loop if the user presses Enter without any input
            else:
                raise ValueError  # show an error for any other input
        except ValueError:
            print("Error: Invalid entry. Please press <ENTER> to start the game.")
            # The loop will continue prompting the user until they press <Enter>

    room_1()

def win():
    
    # Setting script for when participants win
    # Use colorama to add color
    print(Fore.MAGENTA +"""
                                            __             ___             __                                 __     
                                           /\ \__         /\_ \           /\ \__  __                         /\ \    
  ___    ___     ___      __   _ __    __  \ \ ,_\  __  __\//\ \      __  \ \ ,_\/\_\    ___     ___     ____\ \ \   
 /'___\ / __`\ /' _ `\  /'_ `\/\`'__\/'__`\ \ \ \/ /\ \/\ \ \ \ \   /'__`\ \ \ \/\/\ \  / __`\ /' _ `\  /',__\\ \ \  
/\ \__//\ \L\ \/\ \/\ \/\ \L\ \ \ \//\ \L\.\_\ \ \_\ \ \_\ \ \_\ \_/\ \L\.\_\ \ \_\ \ \/\ \L\ \/\ \/\ \/\__, `\\ \_\ 
\ \____\ \____/\ \_\ \_\ \____ \ \_\\ \__/.\_\\ \__\\ \____/ /\____\ \__/.\_\\ \__\\ \_\ \____/\ \_\ \_\/\____/ \/\_\
   \/____/\/___/  \/_/\/_/\/___L\ \/_/ \/__/\/_/ \/__/ \/___/  \/____/\/__/\/_/ \/__/ \/_/\/___/  \/_/\/_/\/___/   \/_/
                           /\____/                                                                                    
                           \_/__/ \n                                                                                    
                 🎉🎉🎉 You've defied all odds and survived the Hunger Games! 🎉🎉🎉\n
                        Your act of bravery paid off, but be careful...         
        Your rebellious act ignited a spark of hope, and the power of the Capitol is weakening.\n
    Careful what you wish for; you may have just started a revolution that will forever change Panem.\n
                    ░▀█▀░█▀█░░░█▀▄░█▀▀░░░█▀▀░█▀█░█▀█░▀█▀░▀█▀░█▀█░█░█░█▀▀░█▀▄░░░░░░
                    ░░█░░█░█░░░█▀▄░█▀▀░░░█░░░█░█░█░█░░█░░░█░░█░█░█░█░█▀▀░█░█░░░░░░
                    ░░▀░░▀▀▀░░░▀▀░░▀▀▀░░░▀▀▀░▀▀▀░▀░▀░░▀░░▀▀▀░▀░▀░▀▀▀░▀▀▀░▀▀░░▀░░▀░
                       """ + Fore.RESET)
    
    ### END OF THE GAME ### 
    input('Press <ENTER> to exit the game : \n')
    exit() # Participants can exit the game

def fail(): 
    
    # Setting script for when participants lose
    print(Fore.MAGENTA + """
                                      Well... That was stupid.
                                    

                 ██████╗  █████╗ ███╗   ███╗███████╗     ██████╗ ██╗   ██╗███████╗██████╗ 
                ██╔════╝ ██╔══██╗████╗ ████║██╔════╝    ██╔═══██╗██║   ██║██╔════╝██╔══██╗
                ██║  ███╗███████║██╔████╔██║█████╗      ██║   ██║██║   ██║█████╗  ██████╔╝
                ██║   ██║██╔══██║██║╚██╔╝██║██╔══╝      ██║   ██║╚██╗ ██╔╝██╔══╝  ██╔══██╗
                ╚██████╔╝██║  ██║██║ ╚═╝ ██║███████╗    ╚██████╔╝ ╚████╔╝ ███████╗██║  ██║
                 ╚═════╝ ╚═╝  ╚═╝╚═╝     ╚═╝╚══════╝     ╚═════╝   ╚═══╝  ╚══════╝╚═╝  ╚═╝
                

""" + Fore.RESET)
    
    ### END OF THE GAME ###
    # Option to try Again
    input('Press <ENTER> to try again :\n')
    intro()
    
#checking if the participants know the Hunger Games universe:
#for loop:
for movie_history in range(3):
    answer = input( prompt = Fore.MAGENTA + """

                            ░█▀▄░█▀▀░█▀▀░█▀█░█▀▄░█▀▀░░░█░█░█▀▀░░░█▀▀░▀█▀░█▀█░█▀▄░▀█▀
                            ░█▀▄░█▀▀░█▀▀░█░█░█▀▄░█▀▀░░░█▄█░█▀▀░░░▀▀█░░█░░█▀█░█▀▄░░█░
                            ░▀▀░░▀▀▀░▀░░░▀▀▀░▀░▀░▀▀▀░░░▀░▀░▀▀▀░░░▀▀▀░░▀░░▀░▀░▀░▀░░▀░
      
                          Are you familiar with the Hunger Games universe? (YES/NO): \n

""" + Fore.RESET)
    
    #condition to ensure entry/keyboard will work with both lower and upper case
    if "y" in answer or "Y" in answer.upper():
        print ("""

                            🏹🏹🏹🏹 Perfect, let's begin then! 🏹🏹🏹🏹
""")
        break #break to go to next room
   
    if "n" in answer or "N" in answer.upper():
        print("""
                    Awh that's okay; the game is pretty straight forward!
                Make sure to follow the instruction and enjoy the adventure! """)
        break 
    
    #Participant can keep trying until they put in a right answer
    else:
        print("Invalid entry. Please enter <YES> or <NO> : .")
        continue
         #The loop will continue prompting the user until they enter <yes> or <no>
        


def room_1(): 
    
    #Setting the script for room 1
    print(Fore.GREEN + """
                                 **************************** \n
                    ░█▀▄░█▀▀░█▀█░█▀█░▀█▀░█▀█░█▀▀░░░█▀▀░█▀▀░█▀▄░█▀▀░█▄█░█▀█░█▀█░█░█
                    ░█▀▄░█▀▀░█▀█░█▀▀░░█░░█░█░█░█░░░█░░░█▀▀░█▀▄░█▀▀░█░█░█░█░█░█░░█░
                    ░▀░▀░▀▀▀░▀░▀░▀░░░▀▀▀░▀░▀░▀▀▀░░░▀▀▀░▀▀▀░▀░▀░▀▀▀░▀░▀░▀▀▀░▀░▀░░▀░ \n
                                 ****************************  \n""" + Fore. RESET)
    
    
    print("""
            The tension is palpable as the ceremony of the 74th edition of the Hunger Games is about to begin. 
               
                   Effie Trinket walks on stage to draw the first Tribute from the Ballot. 
                                 She calls the first name: "Primrose Everdeen."

                                    PRIM. Your little sister.
                                                No. 
                                            It can't be. 

                        Panic grips your chest; you HAVE to make a choice... \n""")
    
    #choice's list
    print(' 1. Volunteer as Tribute 🏹')
    print(' 2. Cry 😭')
    print(' 3. "Oof that sucks sis" 🤷‍♀️ \n ')
    
    while True:
    
    #calling it choice1 so it doesn't get mixed up with other 'choice' (choice2, choice3, choice4,...)
        choice1 = input (prompt = "Insert the <NUMBER> of your choice : \n")
    
        if choice1 == '1':
            print(Fore.GREEN+"""
                                    **************************** """ +Fore.RESET)
            print("""               
                       You have volunteered as tribute to save your little sister Prim.
                                A courageous choice, but at what cost... \n""")
            break #to ensure the loop is closed
        
        elif choice1 == '2':
            print("""
                                    **************************** 
                                      
                    That sure does suck. Thanks for pointing it out Captain Obvious! 
                    You have been spared from participating in the 74th Hunger Games.
                           We will see you at next year Reaping Ceremony! \n""")
            fail()# participants lost - redirect player to the fail() function
                  # call the function before breaking out of the room
            break # Add 'break' to ensure the loop is closed
    
        elif choice1 == '3':
            print(Fore.GREEN+""" 
                                    **************************** 
                                   
             Turns out Prim has a heart attack and can't participate so you have to replace her. 
                                         Karma is a b*tch. 
                                Buckle up, the Hunger Games awaits! \n"""+Fore.RESET)
            break # Add 'break' to ensure the loop is closed
    
        else:
            print("Invalid entry. Please enter one of the <NUMBER> offered in the prompt : ")
            #  The loop will continue prompting the user until they enter a number offered
        
    
    print("""
                The Peacekeepers are shoving you toward the stage as reality kicks in \n
                                     Effie Trinket hands you the mic:
                                     
                That was very brave of you. District 12 hasn't had a volunteer in years.
                                         What is your name? 
                                     
                                     """)
    # Added the 'f' so the tribute name will change depending on the <NAME> the participants enter
    tribute_name = input(prompt = "Enter your <NAME> : \n")
    
    print(f"""\t\t "And, representing District 12 for the 74th edition of the Hunger Games:
    
    
                                            {tribute_name}!""
                                             
                                             OH. NO. \n
                                          
                                       What have you done... """)
    
    #printed emoji/image of the symbol used in Hunger Game when tributes are sent to the arena.
    print(Fore.GREEN + """
                                     
                                                @@@@@@   
                                           @@@@@@@@@@@@@@                                  
                                        @@@@@        @@@@@@                                                     
                                     @@@@@@@@@      @@@     @@@                                                 
                                    @@@     @@@      @@@     @@@                              
                                    @@@     @@@      @@@     @@@                                                 
                                    @@@     @@@      @@@     @@@                              
                                    @@@     @@@      @@@     @@@                                                   
                                    @@@     @@@      @@@     @@@                                                     
                                    @@@     @@@      @@@     @@@                              
                                    @@@                      @@@                              
                                @@@@@@@@                     @@@                              
                             @@@@@@@@@@@@@@@@@@@@@@@@         @@                              
                            @@@@@@                    @@@@@@@@@@@                              
                            @@@@  @@@@@                  @@@@@@@@@                              
                            @@@      @@@@@@@@@                @@@@@                            
                            @@@         @@@@@@@@@@               @@@                              
                            @@@@@@@@@@@@@@@@@@@@@@@@@@@          @@@                            
                            @@@                    @@@@@         @@@                                               
                             @@@                     @@@@       @@@                           
                              @@@                    @@@@@     @@@                              
                                @@@                           @@@                            
                                 @@@                        @@@                                                                                  
                                                        
                                 
                                              """)
    # While loop + 'try' and 'except' to ensure players get to next stage by inputting <ENTER>. 
    while True:
        try:
            go_training_center = input(prompt = 'Press <ENTER> to continue :\n')
            if go_training_center == "":
                break  # Break the loop if the user presses Enter without any input
            else:
                raise ValueError  # show an error for any other input
        except ValueError:
            print("Error: Invalid entry. Please press <ENTER> to continue : \n")
            # The loop will continue prompting the user until they press <Enter>
    room_2()

    
def room_2():
    
    # Setting script for room 2
    print(Fore.BLUE + """
                                    ****************************  \n
                       ░▀█▀░█▀▄░█▀█░▀█▀░█▀█░▀█▀░█▀█░█▀▀░░░█▀▀░█▀▀░█▀█░▀█▀░█▀▀░█▀▄
                       ░░█░░█▀▄░█▀█░░█░░█░█░░█░░█░█░█░█░░░█░░░█▀▀░█░█░░█░░█▀▀░█▀▄
                       ░░▀░░▀░▀░▀░▀░▀▀▀░▀░▀░▀▀▀░▀░▀░▀▀▀░░░▀▀▀░▀▀▀░▀░▀░░▀░░▀▀▀░▀░▀ \n
                                    ****************************  \n """ + Fore.RESET)
    
    print("""
                            You've just arrived at the Capitol's Training Center. 
  Over the next few days, you'll need to undergo physical training, learn survival skills, form alliances, 
    impress Sponsors, and showcase your physical abilities to the Gamemakers during a 'Private Session'. \n
                       Your performance here is KEY to gaining advantages in the arena. 
     Once the games begin, only public approval, Sponsors' support, and your own abilities can save you.\n """)
    
    print(Fore.BLUE+ """
                                    ****************************   \n """ + Fore.RESET)
    
    # Setting script for decision1
    print("""
                              The first challenge focuses on survival skills: 
    In the arena, being stealthy, moving unseen, and knowing how to forage is your best shot at survival. 
                     In this challenge, you must decide on which survival skill to work on. \n  """)
     
    print('Pick one of the following skills to focus on during training: \n')
    print('1. Knowledge of the wilderness 🏞️🥾🌲 ')
    print('2. Camouflage painting and techniques 🔍🤫🎨 ')
    print('3. 30-min yoga routine; DUH! You have to make sure to close those Activity Rings.🧘‍ \n')

    while True: 
        decision1 = input(prompt = "Enter the <NUMBER> associated with your decision :\n")
    
        if decision1 == '1':
            print("""
    That's a great choice; foraging and knowledge can make the difference between life and death in the arena \n """)
            break
        
        elif decision1 == '2':
            print("""
           Great pick! Mastering the art of stealth and camouflage will be essential to your survival. \n""")
            break
        
        elif decision1 == '3': 
            print("""
             WOOPS, a Tributes killed you while you were trying to master your downward-facing dog... \n """)
            fail() # call the function before breaking out of the room
                   # Participants redirected to fail() function
            break
    
        else:
            print("Invalid entry. Please enter one of the <NUMBER> offered in the prompt :\n")
            #The loop will continue prompting the user until they enter a number offered
        
    
    print(Fore.BLUE+ """
                                    ****************************   \n """ + Fore.RESET)
    # Setting scripts choice2
    print("""
    Now it's time for your Private Session with high-profile members of the Capitol and the Gamemakers.
  You must select a weapon and demonstrate your skills to impress your audience and deter your opponents.
    This challenge is also the perfect opportunity to showcase your full potential and attract allies. 
              Remember, forming strategic alliances can be a crucial asset in the Hunger Games. \n """ +Fore.RESET)
    
    print(" Pick the weapon of your choice :\n")
    print(' 1. A bow and arrows 🏹 ')
    print(' 2. A computer, to show those coding skills 💻👾')
    print(' 3. A set of throwing knives 🔪🔪🔪 \n')
    
    while True:
    
        choice2 = input(prompt = 'Enter the <NUMBER> associated with your choice : \n')
    
        if choice2 == '1': 
            print(Fore.BLUE +""" 
                          🏹 Smart, you've always been a great archer! 🏹! \n""" + Fore.RESET)
            break
            
        elif choice2 == '2':
            print(Fore.BLUE + """
                         Not sure there is cellular data in the arena...👾\n """ + Fore.RESET)
            fail() # call the function before breaking out of the room
                   # Participants redirected to fail() function
            break
            
        elif choice2 == '3':
            print( """ 
        
              🔪It's a risky choice, but okay; let's see if you can impress the jury.🔪 \n""" )
            break
    
        else:
            print("Invalid entry. Please enter one of the <NUMBER> offered in the prompt :\n")
            continue
            #The loop will continue prompting the user until they enter a number offered
            
    print (Fore.BLUE+""" 
                                    **************************** """+Fore.RESET)
    # Setting script for choice3
    print("""
                        
                 Good job! You impressed the Sponsors, and two alliances are offered to you. 
                            The issue is both come with their downfalls... 
    
                                                You can either: \n
 1. Ally with Rue - a young Tribute that reminds you of Prim - but give yourself a disadvantage.
 2. Partner up with the strong Tributes, giving you the best shot at survival, but go against your morals. \n""" + Fore.RESET)

    print("""\n                       
 What will it be? Will you: \n      
 1. Follow your heart and pick Rue.
 2. Follow your reason, and partner with district 1 and 2. """)
    
    while True :        
        choice3 = input(prompt = """Enter the <NUMBER> associated with your choice :\n""")
    
        if choice3 == '1' or 'Follow your heart and pick Rue' in choice3:
            print (Fore.BLUE + """
                 What a respectable choice. Let's hope your alliance survive the arena.\n""" + Fore.RESET)
            room_3() # call the function before breaking out of the room
            break
        elif choice3 == '2' or 'Follow your reason, and partner with district 1 and 2' in choice3: 
            print (Fore.BLUE + """
You picked reason, a bright, level-headed choice. Let's hope this alliance helps you survive the Hunger Games.\n""" + Fore.RESET)
            room_3()# call the function before breaking out of the room
            break
        else: 
            print("Invalid entry. Please pick one of the <option> offered in the prompt : \n")
            # The loop will continue prompting the user until they enter one of the <choice3>
            
def room_3(): 
    # Setting script for room 3
    print(Fore.RED + """
                                   ****************************  \n         
                    ░▀█▀░█░█░█▀▀░░░█▀▄░█▀▀░█▀█░▀█▀░█░█░█░░░█░█░░░█▀█░█▀▄░█▀▀░█▀█░█▀█
                    ░░█░░█▀█░█▀▀░░░█░█░█▀▀░█▀█░░█░░█▀█░█░░░░█░░░░█▀█░█▀▄░█▀▀░█░█░█▀█
                    ░░▀░░▀░▀░▀▀▀░░░▀▀░░▀▀▀░▀░▀░░▀░░▀░▀░▀▀▀░░▀░░░░▀░▀░▀░▀░▀▀▀░▀░▀░▀░▀\n 
                                   **************************** \n  
    """ + Fore.RESET)
    print("""\n 
                       The 74th edition of the Hunger Games has officially started!
 You have now entered the deathly arena, a controlled environment designed by the Capitol for this year’s event.\n
         As Tribute, you must wait until the Countdown reaches 0 before you can move or take any actions. 
                     Failure to do so will result in elimination and, thus, death. \n\n
                                     The Countdown begins... \n""")
    
    # instantiating an object
    count = 3

    # looping while count is greater than zero - with a timer of 2 second between each number
    while count > 0:
        print(count) 
        count = count - 1
        time.sleep(2)

    # RUN! - will show once the countdown is done
    print(Fore.RED + """\n                                       
         ███ ███ ███ ███████████   █████  █████ ██████   █████ ██████   █████ ██████   █████ ███ ███ ███
        ░███░███░███░░███░░░░░███ ░░███  ░░███ ░░██████ ░░███ ░░██████ ░░███ ░░██████ ░░███ ░███░███░███
        ░███░███░███ ░███    ░███  ░███   ░███  ░███░███ ░███  ░███░███ ░███  ░███░███ ░███ ░███░███░███
        ░███░███░███ ░██████████   ░███   ░███  ░███░░███░███  ░███░░███░███  ░███░░███░███ ░███░███░███
        ░███░███░███ ░███░░░░░███  ░███   ░███  ░███ ░░██████  ░███ ░░██████  ░███ ░░██████ ░███░███░███
        ░░░ ░░░ ░░░  ░███    ░███  ░███   ░███  ░███  ░░█████  ░███  ░░█████  ░███  ░░█████ ░░░ ░░░ ░░░ 
         ███ ███ ███ █████   █████ ░░████████   █████  ░░█████ █████  ░░█████ █████  ░░█████ ███ ███ ███
        ░░░ ░░░ ░░░ ░░░░░   ░░░░░   ░░░░░░░░   ░░░░░    ░░░░░ ░░░░░    ░░░░░ ░░░░░    ░░░░░ ░░░ ░░░ ░░░  \n """+Fore.RESET)
    time.sleep(2)
    
    # Setting script for choice4
    print("""
                                          All hell breaks lose!
                             Tributes are running everywhere, fighting, dying!\n
 From afar, you see the Cornucopia: the center of the arena containing supplies, weapons, and vital resources. 
            Most Tributes make their way to it or attempt to, but the Cornucopia is hard to reach.
                   Participants risk their lives to get to it then fight each other over the supply. \n
                          You must decide what your next step will be..
        Go hide, find a natural water source, or take a leap of chance and go to the Cornucopia...\n""")
    
    print(Fore.RED +"""                       
                                    **************************** """ + Fore.RESET)
    print("""
                                         
                                 QUICK!! what do you decide to do?\n 
 1. Avoid the massacre and go hide in the forest. 🏃‍♀️🏞️🌲
 2. Go find a the natural water source. 🏃‍♀️ Most recruits will die of natural causes and not combat.
 3. Attempt to make your way to the Cornucopia. 🏃‍♀️ \n """) 
    
    while True:
        choice4 = input(prompt = 'Enter the <NUMBER> associated with your choice: \n')
            
        if choice4 == '1':
            print (Fore.RED + """" 
                  That's a very smart choice! Knowing how and where to hide is key to survival.
                                          Run to the forest area! \n""" + Fore.RESET)
            break
    
        elif choice4 == '2':
            print (Fore.RED + """
                    You're making a great point, water will be a key factor in your survival.
                        Let's go to the forest to try and find a water source! \n """+Fore.RESET)
            break
            
        elif choice4 =='3':
            print("""
                                              A bold choice! 
            Sadly, your bravery didn't pay off.. you ran into another Tribute and lost the Battle.. \n""")
            fail()# Participants redirected to fail() function
                                      
        else: 
            print("Invalid entry. Please enter one of the <NUMBER> offered in the prompt : \n")
            # The loop will continue prompting the user until they enter <1>,<2> or <3>
    
    print("""
                                                🏃‍
                                             
                                                🏃‍
                                             
                                                🏃‍
                                         
            You've made it to the arena's forest and lucked out by finding a built-in hiding room!
        The only issue is that you need to guess the right one-number passcode in order to be let in... \n""" )   

    # importing necessary packages
    import random

    # declaring objects
    number = random.randint(1,3) # random number remains the same for each guess
    chances = 3


    # looping until a user is out of guesses
    while chances > 0:
        choice5 = input(prompt = 'Enter a <NUMBER> between 0 and 3 :\n')
        chances -= 1

        # converting choice for numerical comparison
        choice5 = int(choice5)
    
        # conditional statement based on user input
        if choice5 == number:
            print(Fore.RED + """
          Good job! You've guessed the passcode and can now hide until only one Tribute is left standing!""" +Fore.RESET)
            room_4()

        #user is incorrect
        elif choice5 != number:
            if chances !=0:
                print(Fore.RED + f""" 
                Shoot! You didn't guess the passcode, try again! You have {chances} guesses remaining.""" + Fore.RESET)
            elif chances == 0:
                print(f"""
                                   You are out of guesses. The number was {chances}. 
                          While you were guessing the code, another Tribute shot you in the back...""")
                fail()# Participants redirected to fail() function


    # setting a different error message for inner and outer loops
        else:
            print("\n Invalid entry. Please enter a <NUMBER> between 0 and 3.")
            continue
            # The loop will continue prompting the user until they enter a <number> between 0-3, at least until they run out of chances

def room_4(): 
    
    #Using LIST to put the options
    dilemma_lst = ['Eat deathly berries and both die as an act of rebellion', '3' ]
    dilemma_lst_2 = ['Execute Peeta', '1']
    dilemma_lst_3 = ['Sacrifice yourself', '2']
    
    print(Fore.MAGENTA+""" 
                                    ****************************"""+ Fore.RESET)
    print("""
    
                            Wow! You've fought your way to the final stage!
                             Only one Tribute is left standing beside you. 
                             
         Only there is a slight Problem... it's Peeta - the boy from your district and your lover.. 
                 
           The cruel reality looms over your head. Only one Tribute may survive the Hunger Games.""")

    print("""
 You have 3 options: 

 1. Execute Peeta, ultimately win the Hunger Games, and go home to Prim.
 2. Sacrifice yourself to save the boy you love.
 3. Eat deathly berries, and both die as an act of love and rebellion. """)
    
    dilemma = input(prompt = """
 Enter the <NUMBER> associated with your choice : 
 """)
    if dilemma in dilemma_lst:
        win()
        #participants redirected to the win() function - can exit the game 
    elif dilemma in dilemma_lst_2:
        fail()
        # Participants redirected to fail() function
    elif dilemma in dilemma_lst_3: 
        print(Fore.MAGENTA + """ 
             Shoot! Peeta had the same idea and won the battle ... Better luck next time!""" + Fore.RESET)
        fail()  
        # Participants redirected to fail() function
    else: 
        print("\n Invalid entry. Please enter one of the <option> offered in the prompt : \n")
        # The loop will continue prompting the user until they enter one of the <options> offered
                 
intro()
# Out:
#                             ░█▀▄░█▀▀░█▀▀░█▀█░█▀▄░█▀▀░░░█░█░█▀▀░░░█▀▀░▀█▀░█▀█░█▀▄░▀█▀
#                             ░█▀▄░█▀▀░█▀▀░█░█░█▀▄░█▀▀░░░█▄█░█▀▀░░░▀▀█░░█░░█▀█░█▀▄░░█░
#                             ░▀▀░░▀▀▀░▀░░░▀▀▀░▀░▀░▀▀▀░░░▀░▀░▀▀▀░░░▀▀▀░░▀░░▀░▀░▀░▀░░▀░
#
#                           Are you familiar with the Hunger Games universe? (YES/NO):
#
#
# y
#
#
#                             🏹🏹🏹🏹 Perfect, let's begin then! 🏹🏹🏹🏹
#
#
#
#                                                         +*++==-+#*      =**    ##+
#                                                       =**+=::++*---==  +*#*  *#%#
#                                           *******++++:+++-::--:-+#%+  +### +*%#*
#                                 -:::-::::::::::--::+=+--::-+--=*+*=+*##*+*%#*  %#
#                              :::::::::::::---=+++-+==*::-:-*#+++**+==*+##%## *%#*
#                           ..::::::::::::.....::+==+#---:++-:-#%#++*++=-+##+*##%
# ...

# %% [markdown]
#                                               References:
#
# Grammarly: Free writing AI assistance. (n.d.). https://www.grammarly.com/
#
# Image to ASCII: Free ASCII Art converter. (n.d.). Image to ASCII: Free ASCII Art Converter.
# Retrieved November 22nd, 2023,
# from https://www.asciiart.eu/image-to-ascii#google_vignette
#
# Scribbr. (2023, November 17). Free Citation Generator | APA, MLA, Chicago | Scribbr.
# Retrieved December 2nd, 2023,
# from https://www.scribbr.com/citation/generator/
#
# Text to ASCII: Free ASCII Art converter. (n.d.). Image to ASCII: Free ASCII Art Converter.\n
# Retrieved November 22nd, 2023,
# from
# https://www.asciiart.eu/text-to-ascii-art
#
# Thoman, L. (2023, November 15). The entire hunger games timeline explained. Looper. \n
# Retrieved November 20th, 2023, from
# https://www.looper.com/810795/the-entire-hunger-games-timeline-explained/
#
# Torres, R. (2023, November 20). 'The Hunger Games' movies, ranked from worst to best.
# Collider.
# https://collider.com/hunger-games-movies-ranked-worst-to-best/
#
# OpenAi. (2022). ChatGPT (GPT-4 version) [Large language model].
# https://chat.openai.com/
# Used to help find Hunger Games terms, understand bugs/limitations, discover exit() function, how to 'bold' text and adequately follow APA citation rules.
# Link to the chat: https://chat.openai.com/c/ad8c734b-86ac-4502-92a9-0b11de832438
#
# ![ChatGPTchat](./chatgpt.png)
